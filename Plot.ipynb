# %%
cd /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp34
# Out:
# /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp34

# %%
import pandas as pd
from pandas import DataFrame

# %%
import matplotlib.pyplot as plt
import csv
  
x = []
y = []
  
with open('results.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
        x.append(row[0])
        y.append(row[4])
  
plt.plot(x, y, color = 'r', linestyle = 'dashed',
         marker = '.',label = "Weather Data")
  
plt.xticks(rotation = 25)
plt.xlabel('Dates')
plt.ylabel('Temperature(°C)')
plt.title('Weather Report', fontsize = 20)
plt.grid()
plt.legend()
plt.show()

# %%
result = pd.read_csv('results.csv')

# %%
result
# Out:
#                     epoch        train/box_loss        train/obj_loss  \
# 0                       0              0.079488              0.029275
# 1                       1              0.055995              0.020946
# 2                       2              0.052051              0.019089
# 3                       3              0.049487              0.018682
# 4                       4              0.047194              0.018171
# ..                    ...                   ...                   ...
# 195                   195              0.019138              0.009698
# 196                   196              0.019187              0.009879
# 197                   197              0.019054              0.009896
# 198                   198              0.018613              0.009791
# 199                   199              0.018527              0.009999
#
#            train/cls_loss     metrics/precision        metrics/recall  \
# ...

# %%
ax = plt.gca()

result.plot(x=['epoch'], y=['metric/precision'] , kind = 'line')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_836146/1407793910.py in <module>
#       1 ax = plt.gca()
#       2
# ----> 3 result.plot(x=['epoch'], y=['metric/precision'] , kind = 'line')
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# ...

# %%
x = DataFrame(result, columns=['epoch']).to_numpy
y1 = DataFrame(result, columns=['metric/precision']).to_numpy
y2 = DataFrame(result, columns=['metric/recall']).to_numpy
y3 = DataFrame(result, columns=['metric/mAP_0.5']).to_numpy
y4 = DataFrame(result, columns=['metric/mAP_0.5:0.95']).to_numpy

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
y1
# Out:
# <bound method DataFrame.to_numpy of      metric/precision
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 195               NaN
# 196               NaN
# 197               NaN
# 198               NaN
# 199               NaN
#
# [200 rows x 1 columns]>

# %%
y1
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
# ...

# %%
plt.plot(x, y1)
