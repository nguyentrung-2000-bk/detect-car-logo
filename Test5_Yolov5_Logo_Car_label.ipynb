# %%
cd /data/trungnv/Object_Detection/YOLOv5/
# Out:
# /data/trungnv/Object_Detection/YOLOv5

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# import zipfile as zf

# files = zf.ZipFile("train_data.zip",'r')
# files.extractall()
# files.close()

# %%
import torch
import os
from yolov5 import utils

# %%
os.environ['CUDA_VISIBLE_DEVICES']='1'
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2022-07-22 15:08:09.106906: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
cd yolov5/
# Out:
# /data/trungnv/Object_Detection/YOLOv5/yolov5

# %%
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
# Setup complete ✅ (48 CPUs, 125.6 GB RAM, 316.6/372.2 GB disk)

# %%
# Train YOLOv5
# !python train.py --img 640 --batch 64 --epochs 200 --data custom_data.yaml --weights yolov5s.pt
# !python train.py --img 640 --batch 32 --epochs 5 --data custom_data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 50 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2022-07-22 15:09:50.611737: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Overriding model.yaml nc=80 with nc=35
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    107880  models.yolo.Detect                      [35, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7114024 parameters, 7114024 gradients, 16.2 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: Blur(always_apply=False, p=0.01, blur_limit=(3, 7)), MedianBlur(always_apply=False, p=0.01, blur_limit=(3, 7)), ToGray(always_apply=False, p=0.01), CLAHE(always_apply=False, p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/data/trungnv/Object_Detection/YOLOv5/yolov5/data/train_data/la
# val: Scanning '/data/trungnv/Object_Detection/YOLOv5/yolov5/data/train_data/labe
# Plotting labels to runs/train/exp41/labels.jpg...
#
# AutoAnchor: 3.28 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp41
# Starting training for 200 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/199     13.9G   0.08133   0.02928   0.08796        26       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1049      0.497     0.0632     0.0134    0.00525
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/199     19.1G   0.05923   0.01967   0.07745        19       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1021      0.671      0.103     0.0306     0.0118
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/199     19.1G   0.05125   0.01827   0.07236        44       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.681      0.106     0.0501     0.0236
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/199     19.1G   0.04823   0.01708   0.06616        36       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.557       0.13     0.0862     0.0428
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/199     19.1G   0.04553   0.01685   0.05923        32       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1033      0.713      0.146      0.143      0.077
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/199     19.1G   0.04439   0.01645   0.05258        35       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.755      0.226      0.212      0.111
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/199     19.1G   0.04186   0.01603   0.04841        37       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.796      0.316      0.322      0.174
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/199     19.1G   0.04188   0.01546   0.04216        26       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        939      0.751      0.338      0.336      0.183
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/199     19.1G   0.04113   0.01521   0.04188        43       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        969      0.775      0.292      0.308      0.148
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/199     19.1G   0.04032   0.01546   0.03785        37       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.667      0.316      0.309      0.163
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/199     19.1G   0.03923   0.01511   0.03455        28       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.715      0.399       0.41      0.205
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/199     19.1G   0.03968   0.01505   0.03606        39       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        935      0.689      0.373      0.392      0.212
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/199     19.1G   0.04007   0.01491   0.03382        29       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        929      0.722      0.449      0.461      0.255
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/199     19.1G   0.03801   0.01463   0.03248        33       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.795      0.467      0.534      0.299
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/199     19.1G   0.03811   0.01472   0.02938        37       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        731      0.805      0.472      0.542       0.32
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/199     19.1G   0.03918   0.01432   0.02961        26       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.711      0.484      0.539        0.3
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/199     19.1G   0.03812   0.01431   0.02748        33       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        833      0.686      0.576      0.588      0.343
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/199     19.1G   0.03692   0.01407   0.02599        28       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0.718       0.47       0.51      0.279
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/199     19.1G   0.03744   0.01405   0.02506        32       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1030      0.772      0.559      0.605      0.362
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/199     19.1G   0.03664   0.01411   0.02432        33       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        972      0.797      0.596      0.651      0.394
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/199     19.1G     0.038   0.01403   0.02579        31       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        962      0.828      0.551      0.654      0.389
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/199     19.1G   0.03693   0.01403   0.02192        41       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        918      0.819      0.593      0.688      0.393
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/199     19.1G   0.03578   0.01374   0.02215        29       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937        992      0.782      0.644      0.688      0.413
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/199     19.1G   0.03505   0.01348   0.01993        42       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@WARNING: NMS time limit 4.140s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1008      0.808      0.621      0.685      0.403
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/199     19.1G   0.03591   0.01389   0.02061        35       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1050      0
0.689
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    199/199     19.1G    0.0147   0.00793  0.002167        30       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1043      0.926      0.886      0.928       0.69
#
# 200 epochs completed in 2.812 hours.
# Optimizer stripped from runs/train/exp41/weights/last.pt, 14.6MB
# Optimizer stripped from runs/train/exp41/weights/best.pt, 14.6MB
#
# Validating runs/train/exp41/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7104520 parameters, 0 gradients, 16.0 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        937       1043      0.928      0.887      0.931      0.693
#               akurra        937         21      0.978          1      0.995      0.903
#             arrinera        937          8      0.767      0.875      0.819      0.681
#              Benelli        937         20      0.941      0.794        0.9      0.621
#              Bentley        937         35          1       0.87      0.952      0.688
#                  BMW        937         15          1      0.941      0.995      0.728
#              bolwell        937         10      0.913        0.7      0.707      0.425
#          Bridgestone        937         19          1      0.682      0.923      0.653
#              BUGATTI        937         22      0.971          1      0.995       0.91
#               Caparo        937          6      0.743          1      0.995      0.908
#                Chery        937         23      0.975          1      0.995      0.817
#            Chevrolet        937         14      0.966      0.929      0.979      0.654
#              Chevron        937         45      0.884      0.933      0.962      0.703
#                Dacia        937         22      0.984          1      0.995      0.559
#              ginetta        937         10       0.92          1      0.995      0.873
#              gleagle        937         14      0.969      0.714      0.902       0.59
#              gumpert        937         22      0.966      0.909      0.955      0.865
#              hyundai        937         81          1      0.951      0.979      0.906
#                 ikco        937         13      0.965          1      0.995      0.851
#               jinbei        937         10      0.959          1      0.995      0.668
#               kia da        937         46      0.951      0.957      0.961      0.756
#                 Lada        937          6      0.887      0.833      0.841       0.52
#          Lamborghini        937         18          1          1      0.995      0.591
#               Lancia        937         17      0.871      0.795      0.846      0.515
#           land rover        937          6      0.856      0.989      0.948      0.607
#              levante        937          3      0.833          1      0.995      0.549
#             Marussia        937         21      0.774      0.667      0.712      0.394
#             Maserati        937         24      0.784      0.756      0.895      0.527
#                Mazda        937         32      0.917       0.69      0.936      0.631
#                  MDX        937          7          1      0.569      0.682       0.43
#             mercedes        937        101      0.943      0.974      0.988      0.902
#                 opel        937         84          1      0.951      0.981       0.87
#               r-line        937         49          1      0.956       0.99      0.659
#                skoda        937         66      0.995      0.939       0.96      0.857
#               toyota        937         51      0.782      0.725       0.83      0.549
#           volkswagen        937        102       0.99       0.94      0.983      0.897
# Results saved to runs/train/exp41
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f367042d200>
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1262, in _shutdown_workers
# AttributeError: 'NoneType' object has no attribute 'python_exit_status'
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f367042d200>
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1328, in __del__
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1262, in _shutdown_workers
# AttributeError: 'NoneType' object has no attribute 'python_exit_status'

# %%
# %%time

# !python detect.py --weights /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp34/weights/best.pt \
--img 3000 --conf 0.5 --source data/images/mazda-cx-30-1.jpg
# Out:
# detect: weights=['/data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp34/weights/best.pt'], source=data/images/mazda-cx-30-1.jpg, data=data/coco128.yaml, imgsz=[3000, 3000], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7190824 parameters, 0 gradients, 16.3 GFLOPs
# WARNING: --img-size [3000, 3000] must be multiple of max stride 32, updating to [3008, 3008]
# image 1/1 /data/trungnv/Object_Detection/YOLOv5/yolov5/data/images/mazda-cx-30-1.jpg: 1920x3008 1 maybach-2, 1 Mazda, Done. (0.025s)
# Speed: 4.3ms pre-process, 25.2ms inference, 1.8ms NMS per image at shape (1, 3, 3008, 3008)
# Results saved to runs/detect/exp27
# CPU times: user 161 ms, sys: 56 ms, total: 217 ms
# Wall time: 10.6 s

# %%
display.Image(filename='runs/detect/exp27/mazda-cx-30-1.jpg', width=600)

# %%
# %%time

# !python detect.py --weights /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp23/weights/best.pt \
--img 960 --conf 0.25 --source data/images/bmw-840i-2-3592.jpg
# Out:
# detect: weights=['/data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp23/weights/best.pt'], source=data/images/bmw-840i-2-3592.jpg, data=data/coco128.yaml, imgsz=[960, 960], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7584586 parameters, 0 gradients, 17.6 GFLOPs
# image 1/1 /data/trungnv/Object_Detection/YOLOv5/yolov5/data/images/bmw-840i-2-3592.jpg: 736x960 1 BMW, Done. (0.015s)
# Speed: 0.8ms pre-process, 15.3ms inference, 1.7ms NMS per image at shape (1, 3, 960, 960)
# Results saved to runs/detect/exp16
# CPU times: user 166 ms, sys: 64.5 ms, total: 231 ms
# Wall time: 10.7 s

# %%
display.Image(filename='runs/detect/exp16/bmw-840i-2-3592.jpg', width=600)

# %%
# %%time

# !python detect.py --weights /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp23/weights/best.pt \
--img 1280 --conf 0.25 --source data/images/CjcNYyxlE1.jpg
# Out:
# detect: weights=['/data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp23/weights/best.pt'], source=data/images/CjcNYyxlE1.jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7584586 parameters, 0 gradients, 17.6 GFLOPs
# image 1/1 /data/trungnv/Object_Detection/YOLOv5/yolov5/data/images/CjcNYyxlE1.jpg: 896x1280 1 Brooks Saddle, Done. (0.017s)
# Speed: 1.2ms pre-process, 16.9ms inference, 2.1ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp20
# CPU times: user 162 ms, sys: 57.6 ms, total: 219 ms
# Wall time: 10.7 s

# %%
display.Image(filename='runs/detect/exp20/CjcNYyxlE1.jpg', width=600)

# %%
# %%time

# !python detect.py --weights /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp14/weights/best.pt --img 640 --conf 0.25 --source data/images/155620544344277-thumbnail.jpg
# Out:
# detect: weights=['/data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp14/weights/best.pt'], source=data/images/155620544344277-thumbnail.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /data/trungnv/Object_Detection/YOLOv5/yolov5/data/images/155620544344277-thumbnail.jpg: 416x640 1 military tank, Done. (0.013s)
# Speed: 0.4ms pre-process, 12.8ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp12
# CPU times: user 158 ms, sys: 34.6 ms, total: 192 ms
# Wall time: 10.1 s

# %%
display.Image(filename='runs/detect/exp11/155620544344277-thumbnail.jpg', width=600)

# %%
# %%time

# !python detect.py --weights /data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp14/weights/best.pt \
        --img 640 --conf 0.25 --source data/images/cdc-tq-9817.jpeg
# Out:
# detect: weights=['/data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp14/weights/best.pt'], source=data/images/cdc-tq-9817.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /data/trungnv/Object_Detection/YOLOv5/yolov5/data/images/cdc-tq-9817.jpeg: 384x640 2 civilian aircrafts, 2 military aircrafts, Done. (0.024s)
# Speed: 0.4ms pre-process, 24.0ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp14
# CPU times: user 144 ms, sys: 47.8 ms, total: 192 ms
# Wall time: 10.3 s

# %%
display.Image(filename='runs/detect/exp14/cdc-tq-9817.jpeg', width=600)

# %%
# !python detect.py --weights data/trungnv/Object_Detection/YOLOv5/yolov5/runs/train/exp9/weights/best.pt --img 640 --conf 0.25 --source data/images/8.jpg
display.Image(filename='runs/detect/exp/8.jpg', width=600)
# Out:
# detect: weights=['/runs/train/exp9/weights/best.pt'], source=data/images/8.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/runs/train/exp9/weights'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/runs/train/exp9'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/runs/train'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "detect.py", line 252, in <module>
#     main(opt)
#   File "detect.py", line 247, in main
#     run(**vars(opt))
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/data/trungnv/Object_Detection/YOLOv5/yolov5/models/common.py", line 326, in __init__
#     w = attempt_download(w)  # download if not local
#   File "/data/trungnv/Object_Detection/YOLOv5/yolov5/utils/downloads.py", line 94, in attempt_download
#     file.parent.mkdir(parents=True, exist_ok=True)  # make parent dir (if required)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1277, in mkdir
#     self.parent.mkdir(parents=True, exist_ok=True)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1277, in mkdir
#     self.parent.mkdir(parents=True, exist_ok=True)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1277, in mkdir
#     self.parent.mkdir(parents=True, exist_ok=True)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/runs'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_113838/646278207.py in <module>
#       1 get_ipython().system('python detect.py --weights /runs/train/exp9/weights/best.pt --img 640 --conf 0.25 --source data/images/8.jpg')
# ----> 2 display.Image(filename='runs/detect/exp/8.jpg', width=600)
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/detect/exp/8.jpg'

# %%
# !python detect.py --weights /runs/train/exp9/weights/best.pt --img 640 --conf 0.25 --source data/images/155620544344277-thumbnail.jpg
display.Image(filename='/yolov5/runs/detect/exp/dinhdoclap.jpg', width=600)
# Out:
# detect: weights=['/runs/train/exp9/weights/best.pt'], source=data/images/155620544344277-thumbnail.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.10.1+cu111 CUDA:0 (GeForce RTX 3090, 24268MiB)
#
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/runs/train/exp9/weights'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/runs/train/exp9'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/runs/train'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "detect.py", line 252, in <module>
#     main(opt)
#   File "detect.py", line 247, in main
#     run(**vars(opt))
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/data/trungnv/Object_Detection/YOLOv5/yolov5/models/common.py", line 326, in __init__
#     w = attempt_download(w)  # download if not local
#   File "/data/trungnv/Object_Detection/YOLOv5/yolov5/utils/downloads.py", line 94, in attempt_download
#     file.parent.mkdir(parents=True, exist_ok=True)  # make parent dir (if required)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1277, in mkdir
#     self.parent.mkdir(parents=True, exist_ok=True)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1277, in mkdir
#     self.parent.mkdir(parents=True, exist_ok=True)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1277, in mkdir
#     self.parent.mkdir(parents=True, exist_ok=True)
#   File "/data/trungnv/anaconda3/envs/my_env/lib/python3.7/pathlib.py", line 1273, in mkdir
#     self._accessor.mkdir(self, mode)
# PermissionError: [Errno 13] Permission denied: '/runs'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_113838/2335414965.py in <module>
#       1 get_ipython().system('python detect.py --weights /runs/train/exp9/weights/best.pt --img 640 --conf 0.25 --source data/images/155620544344277-thumbnail.jpg')
# ----> 2 display.Image(filename='/yolov5/runs/detect/exp/dinhdoclap.jpg', width=600)
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /data/trungnv/anaconda3/envs/my_env/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/yolov5/runs/detect/exp/dinhdoclap.jpg'
